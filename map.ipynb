# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
df = pd.read_csv('files/weatherAUS.csv')
df
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0                0  2008-12-01   Albury     13.4     22.9       0.6
# 1                1  2008-12-02   Albury      7.4     25.1       0.0
# 2                2  2008-12-03   Albury     12.9     25.7       0.0
# 3                3  2008-12-04   Albury      9.2     28.0       0.0
# 4                4  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 145407      145454  2017-06-20    Uluru      3.5     21.8       0.0
# 145408      145455  2017-06-21    Uluru      2.8     23.4       0.0
# 145409      145456  2017-06-22    Uluru      3.6     25.3       0.0
# 145410      145457  2017-06-23    Uluru      5.4     26.9       0.0
# 145411      145458  2017-06-24    Uluru      7.8     27.0       0.0
#
#         Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm  \
# 0               NaN       NaN           W           44.0  ...        22.0
# 1               NaN       NaN         WNW           44.0  ...        25.0
# 2               NaN       NaN         WSW           46.0  ...        30.0
# 3               NaN       NaN          NE           24.0  ...        16.0
# 4               NaN       NaN           W           41.0  ...        33.0
# ...             ...       ...         ...            ...  ...         ...
# 145407          NaN       NaN           E           31.0  ...        27.0
# 145408          NaN       NaN           E           31.0  ...        24.0
# 145409          NaN       NaN         NNW           22.0  ...        21.0
# 145410          NaN       NaN           N           37.0  ...        24.0
# 145411          NaN       NaN          SE           28.0  ...        24.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0           1007.7       1007.1       8.0       NaN     16.9     21.8
# 1           1010.6       1007.8       NaN       NaN     17.2     24.3
# 2           1007.6       1008.7       NaN       2.0     21.0     23.2
# 3           1017.6       1012.8       NaN       NaN     18.1     26.5
# 4           1010.8       1006.0       7.0       8.0     17.8     29.7
# ...            ...          ...       ...       ...      ...      ...
# 145407      1024.7       1021.2       NaN       NaN      9.4     20.9
# 145408      1024.6       1020.3       NaN       NaN     10.1     22.4
# 145409      1023.5       1019.1       NaN       NaN     10.9     24.5
# 145410      1021.0       1016.8       NaN       NaN     12.5     26.1
# 145411      1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RainTomorrow  RainfallTomorrow
# 0              No            No               0.0
# 1              No            No               0.0
# 2              No            No               0.0
# 3              No            No               1.0
# 4              No            No               0.2
# ...           ...           ...               ...
# 145407         No            No               0.0
# 145408         No            No               0.0
# 145409         No            No               0.0
# 145410         No            No               0.0
# 145411         No            No               0.0
#
# [145412 rows x 25 columns]

# %%
#Create a new column with the coordinates of each city
cities_coord = {'Adelaide': (-34.9285, 138.6007),
                'Albany': (-35.0031, 117.8657),
                'Albury': (-36.0737, 146.9135),
                'AliceSprings': (-23.6980, 133.8807),
                'BadgerysCreek': (-33.8813, 150.7400),
                'Ballarat': (-37.5622, 143.8503),
                'Bendigo': (-36.7570, 144.2794),
                'Brisbane': (-27.4698, 153.0251),
                'Cairns': (-16.9186, 145.7781),
                'Canberra': (-35.2809, 149.1300),
                'Cobar': (-31.4983, 145.8344),
                'CoffsHarbour': (-30.2963, 153.1131),
                'Dartmoor': (-37.9223, 141.2760),
                'Darwin': (-12.4634, 130.8456),
                'GoldCoast': (-28.0167, 153.4000),
                'Hobart': (-42.8821, 147.3272),
                'Katherine': (-14.4644, 132.2630),
                'Launceston': (-41.4545, 147.1317),
                'Melbourne': (-37.8136, 144.9631),
                'MelbourneAirport': (-37.6690, 144.8410),
                'Mildura': (-34.2083, 142.1270),
                'Moree': (-29.4638, 149.8413),
                'MountGambier': (-37.8241, 140.7798),
                'MountGinini': (-35.5294, 148.7720),
                'Newcastle': (-32.9283, 151.7817),
                'Nhil': (-36.3328, 141.6503),
                'NorahHead': (-33.2833, 151.5667),
                'NorfolkIsland': (-29.0408, 167.9547),
                'Nuriootpa': (-34.4667, 138.9833),
                'PearceRAAF': (-31.6675, 116.0158),
                'Penrith': (-33.7581, 150.6950),
                'Perth': (-31.9522, 115.8589),
                'PerthAirport': (-31.9405, 115.9660),
                'Portland': (-38.3511, 141.6056),
                'Richmond': (-33.6000, 150.7500),
                'Sale': (-38.1063, 147.0674),
                'SalmonGums': (-32.9819, 121.6431),
                'Sydney': (-33.8688, 151.2093),
                'SydneyAirport': (-33.9461, 151.1772),
                'Townsville': (-19.2583, 146.8169),
                'Tuggeranong': (-35.4244, 149.0887),
                'Uluru': (-25.3444, 131.0369),
                'WaggaWagga': (-35.1082, 147.3598),
                'Walpole': (-34.9772, 116.7317),
                'Watsonia': (-37.7114, 145.0831),
                'Williamtown': (-32.8150, 151.8428),
                'Witchcliffe': (-34.0264, 115.1000),
                'Wollongong': (-34.4241, 150.8931),
                'Woomera': (-31.1997, 136.8256)}

#Create a new column with the coordinates of each city
df['Coordinates'] = df['Location'].map(cities_coord)

#Create two new columns with the latitude and longitude of each city
df[['Latitude', 'Longitude']] = df['Coordinates'].apply(pd.Series)

#Create a new column with the geometry of each city
df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
df['Coordinates'] = df['Coordinates'].apply(Point)
df

#Create a new dataframe with the geometry of each city
gdf = gpd.GeoDataFrame(df, geometry='Coordinates')
gdf
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0                0  2008-12-01   Albury     13.4     22.9       0.6
# 1                1  2008-12-02   Albury      7.4     25.1       0.0
# 2                2  2008-12-03   Albury     12.9     25.7       0.0
# 3                3  2008-12-04   Albury      9.2     28.0       0.0
# 4                4  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 145407      145454  2017-06-20    Uluru      3.5     21.8       0.0
# 145408      145455  2017-06-21    Uluru      2.8     23.4       0.0
# 145409      145456  2017-06-22    Uluru      3.6     25.3       0.0
# 145410      145457  2017-06-23    Uluru      5.4     26.9       0.0
# 145411      145458  2017-06-24    Uluru      7.8     27.0       0.0
#
#         Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Cloud9am  \
# 0               NaN       NaN           W           44.0  ...      8.0
# 1               NaN       NaN         WNW           44.0  ...      NaN
# 2               NaN       NaN         WSW           46.0  ...      NaN
# 3               NaN       NaN          NE           24.0  ...      NaN
# 4               NaN       NaN           W           41.0  ...      7.0
# ...             ...       ...         ...            ...  ...      ...
# 145407          NaN       NaN           E           31.0  ...      NaN
# 145408          NaN       NaN           E           31.0  ...      NaN
# 145409          NaN       NaN         NNW           22.0  ...      NaN
# 145410          NaN       NaN           N           37.0  ...      NaN
# 145411          NaN       NaN          SE           28.0  ...      3.0
#
#        Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  RainfallTomorrow  \
# 0           NaN     16.9     21.8         No            No               0.0
# 1           NaN     17.2     24.3         No            No               0.0
# 2           2.0     21.0     23.2         No            No               0.0
# 3           NaN     18.1     26.5         No            No               1.0
# 4           8.0     17.8     29.7         No            No               0.2
# ...         ...      ...      ...        ...           ...               ...
# 145407      NaN      9.4     20.9         No            No               0.0
# 145408      NaN     10.1     22.4         No            No               0.0
# 145409      NaN     10.9     24.5         No            No               0.0
# 145410      NaN     12.5     26.1         No            No               0.0
# 145411      2.0     15.1     26.0         No            No               0.0
#
#                         Coordinates  Latitude  Longitude
# 0       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 1       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 2       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 3       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 4       POINT (146.91350 -36.07370)  -36.0737   146.9135
# ...                             ...       ...        ...
# 145407  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145408  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145409  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145410  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145411  POINT (131.03690 -25.34440)  -25.3444   131.0369
#
# [145412 rows x 28 columns]

# %%
gdf.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am',
#        'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow', 'RainfallTomorrow',
#        'Coordinates', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
#Check the map
fig, ax = plt.subplots(figsize=(15,15))
map_df.plot(ax=ax, alpha=0.4, color='grey')
gdf.plot(ax=ax, markersize=20, color='red', marker='o', label='Cities')
plt.legend(prop={'size': 15})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 5 line <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> #Check the map
#       <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> fig, ax = plt.subplots(figsize=(15,15))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> map_df.plot(ax=ax, alpha=0.4, color='grey')
#       <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> gdf.plot(ax=ax, markersize=20, color='red', marker='o', label='Cities')
#       <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> plt.legend(prop={'size': 15})
#
# NameError: name 'map_df' is not defined

# %%
gdf
# Out:
#         Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  \
# 0                0  2008-12-01   Albury     13.4     22.9       0.6
# 1                1  2008-12-02   Albury      7.4     25.1       0.0
# 2                2  2008-12-03   Albury     12.9     25.7       0.0
# 3                3  2008-12-04   Albury      9.2     28.0       0.0
# 4                4  2008-12-05   Albury     17.5     32.3       1.0
# ...            ...         ...      ...      ...      ...       ...
# 145407      145454  2017-06-20    Uluru      3.5     21.8       0.0
# 145408      145455  2017-06-21    Uluru      2.8     23.4       0.0
# 145409      145456  2017-06-22    Uluru      3.6     25.3       0.0
# 145410      145457  2017-06-23    Uluru      5.4     26.9       0.0
# 145411      145458  2017-06-24    Uluru      7.8     27.0       0.0
#
#         Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Cloud9am  \
# 0               NaN       NaN           W           44.0  ...      8.0
# 1               NaN       NaN         WNW           44.0  ...      NaN
# 2               NaN       NaN         WSW           46.0  ...      NaN
# 3               NaN       NaN          NE           24.0  ...      NaN
# 4               NaN       NaN           W           41.0  ...      7.0
# ...             ...       ...         ...            ...  ...      ...
# 145407          NaN       NaN           E           31.0  ...      NaN
# 145408          NaN       NaN           E           31.0  ...      NaN
# 145409          NaN       NaN         NNW           22.0  ...      NaN
# 145410          NaN       NaN           N           37.0  ...      NaN
# 145411          NaN       NaN          SE           28.0  ...      3.0
#
#        Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  RainfallTomorrow  \
# 0           NaN     16.9     21.8         No            No               0.0
# 1           NaN     17.2     24.3         No            No               0.0
# 2           2.0     21.0     23.2         No            No               0.0
# 3           NaN     18.1     26.5         No            No               1.0
# 4           8.0     17.8     29.7         No            No               0.2
# ...         ...      ...      ...        ...           ...               ...
# 145407      NaN      9.4     20.9         No            No               0.0
# 145408      NaN     10.1     22.4         No            No               0.0
# 145409      NaN     10.9     24.5         No            No               0.0
# 145410      NaN     12.5     26.1         No            No               0.0
# 145411      2.0     15.1     26.0         No            No               0.0
#
#                         Coordinates  Latitude  Longitude
# 0       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 1       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 2       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 3       POINT (146.91350 -36.07370)  -36.0737   146.9135
# 4       POINT (146.91350 -36.07370)  -36.0737   146.9135
# ...                             ...       ...        ...
# 145407  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145408  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145409  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145410  POINT (131.03690 -25.34440)  -25.3444   131.0369
# 145411  POINT (131.03690 -25.34440)  -25.3444   131.0369
#
# [145412 rows x 28 columns]

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 6 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> df.columns()
#
# TypeError: 'Index' object is not callable

# %%
import matplotlib.pyplot as plt
import numpy as np

# Supongamos que tienes un DataFrame llamado df con las columnas mencionadas y datos reales

# Simula direcciones y velocidades del viento (puedes usar tus propios datos reales)
wind_directions = gdf['WindGustDir'].unique()
wind_speeds = np.random.randint(5, 20, len(wind_directions))

# Crea un gráfico del mapa de Australia
fig, ax = plt.subplots(figsize=(15, 15))
map_df.plot(ax=ax, alpha=0.4, color='grey')

# Dibuja vectores de viento en las ubicaciones de las ciudades
for index, row in gdf.iterrows():
    city = row['Location']
    lat = row['Latitude']
    lon = row['Longitude']
    wind_dir = row['WindGustDir']
    wind_speed = wind_speeds[wind_directions.index(wind_dir)]

    # Convierte la dirección del viento en un ángulo en radianes
    angle = wind_directions.index(wind_dir) * (2 * np.pi / len(wind_directions))

    # Calcula los componentes x e y del vector de viento
    u = wind_speed * np.cos(angle)
    v = wind_speed * np.sin(angle)

    # Dibuja el vector de viento en la ubicación de la ciudad
    ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=1, color='blue', alpha=0.7)

# Añade un título y muestra el gráfico
plt.title('Campo Vectorial de Dirección del Viento en Australia', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 8 line <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X10sZmlsZQ%3D%3D?line=17'>18</a> lon = row['Longitude']
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> wind_dir = row['WindGustDir']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a> wind_speed = wind_speeds[wind_directions.index(wind_dir)]
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> # Convierte la dirección del viento en un ángulo en radianes
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a> angle = wind_directions.index(wind_dir) * (2 * np.pi / len(wind_directions))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

# Supongamos que tienes un DataFrame llamado df con las columnas mencionadas y datos reales

# Crea un GeoDataFrame a partir del DataFrame original
gdf = gpd.GeoDataFrame(df, 
                       geometry=df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1), 
                       crs="EPSG:4326")

# Obtiene todas las direcciones únicas del viento presentes en el DataFrame
unique_wind_directions = df['WindGustDir'].dropna().unique()

# Crea un gráfico del mapa de Australia
fig, ax = plt.subplots(figsize=(15, 15))
map_df.plot(ax=ax, alpha=0.4, color='grey')

# Dibuja vectores de viento en las ubicaciones de las ciudades para cada dirección única
for wind_dir in unique_wind_directions:
    wind_dir_df = gdf[gdf['WindGustDir'] == wind_dir]
    
    for index, row in wind_dir_df.iterrows():
        city = row['Location']
        lat = row['Latitude']
        lon = row['Longitude']
        wind_speed = row['WindGustSpeed']

        if not np.isnan(wind_speed):
            # Convierte la dirección del viento en un ángulo en radianes
            wind_directions = unique_wind_directions
            angle = (wind_directions.tolist().index(wind_dir) * (360/len(unique_wind_directions))) * (np.pi / 180)

            # Calcula los componentes x e y del vector de viento
            u = wind_speed * np.cos(angle)
            v = wind_speed * np.sin(angle)

            # Dibuja el vector de viento en la ubicación de la ciudad
            ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=1, color='blue', alpha=0.7)

# Añade un título y muestra el gráfico
plt.title('Campo Vectorial de Dirección del Viento en Australia', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 9 line <cell line: 21>()
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X12sZmlsZQ%3D%3D?line=36'>37</a>             v = wind_speed * np.sin(angle)
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X12sZmlsZQ%3D%3D?line=38'>39</a>             # Dibuja el vector de viento en la ubicación de la ciudad
# ---> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X12sZmlsZQ%3D%3D?line=39'>40</a>             ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=1, color='blue', alpha=0.7)
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X12sZmlsZQ%3D%3D?line=41'>42</a> # Añade un título y muestra el gráfico
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X12sZmlsZQ%3D%3D?line=42'>43</a> plt.title('Campo Vectorial de Dirección del Viento en Australia', fontsize=16)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_axes.py:4982, in Axes.quiver(self, *args, **kwargs)
#    4980 args = self._quiver_units(args, kwargs)
#    4981 q = mquiver.Quiver(self, *args, **kwargs)
# -> 4982 self.add_collection(q, autolim=True)
#    4983 self._request_autoscale_view()
#    4984 return q
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2247, in _AxesBase.add_collection(self, collection, autolim)
#    2242     collection.set_clip_path(self.patch)
#    2244 if autolim:
#    2245     # Make sure viewLim is not stale (mostly to match
#    2246     # pre-lazy-autoscale behavior, which is not really better).
# -> 2247     self._unstale_viewLim()
#    2248     datalim = collection.get_datalim(self.transData)
#    2249     points = datalim.get_points()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:777, in _AxesBase._unstale_viewLim(self)
#     775     for ax in self._shared_axes[name].get_siblings(self):
#     776         ax._stale_viewlims[name] = False
# --> 777 self.autoscale_view(**{f"scale{name}": scale
#     778                        for name, scale in need_scale.items()})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2862, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    2856         x_stickies = np.sort(np.concatenate([
#    2857             artist.sticky_edges.x
#    2858             for ax in self._shared_axes["x"].get_siblings(self)
#    2859             if hasattr(ax, "_children")
#    2860             for artist in ax.get_children()]))
#    2861     if self._ymargin and scaley and self._autoscaleYon:
# -> 2862         y_stickies = np.sort(np.concatenate([
#    2863             artist.sticky_edges.y
#    2864             for ax in self._shared_axes["y"].get_siblings(self)
#    2865             if hasattr(ax, "_children")
#    2866             for artist in ax.get_children()]))
#    2867 if self.get_xscale() == 'log':
#    2868     x_stickies = x_stickies[x_stickies > 0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2863, in <listcomp>(.0)
#    2856         x_stickies = np.sort(np.concatenate([
#    2857             artist.sticky_edges.x
#    2858             for ax in self._shared_axes["x"].get_siblings(self)
#    2859             if hasattr(ax, "_children")
#    2860             for artist in ax.get_children()]))
#    2861     if self._ymargin and scaley and self._autoscaleYon:
#    2862         y_stickies = np.sort(np.concatenate([
# -> 2863             artist.sticky_edges.y
#    2864             for ax in self._shared_axes["y"].get_siblings(self)
#    2865             if hasattr(ax, "_children")
#    2866             for artist in ax.get_children()]))
#    2867 if self.get_xscale() == 'log':
#    2868     x_stickies = x_stickies[x_stickies > 0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:1111, in Artist.sticky_edges(self)
#    1108     self.pchanged()
#    1109     self.stale = True
# -> 1111 @property
#    1112 def sticky_edges(self):
#    1113     """
#    1114     ``x`` and ``y`` sticky edge lists for autoscaling.
#    1115
#    (...)
#    1134
#    1135     """
#    1136     return self._sticky_edges
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

def plot_wind_vectors(df, date):
    # Crea un GeoDataFrame a partir del DataFrame original
    gdf = gpd.GeoDataFrame(df, 
                           geometry=df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1), 
                           crs="EPSG:4326")

    # Filtra los datos para la fecha especificada
    df_filtered = gdf[gdf['Date'] == date]

    if df_filtered.empty:
        print(f"No hay datos disponibles para la fecha {date}.")
        return

    # Obtiene todas las direcciones únicas del viento presentes en los datos filtrados
    unique_wind_directions = df_filtered['WindGustDir'].dropna().unique()

    # Crea un gráfico del mapa de Australia
    fig, ax = plt.subplots(figsize=(15, 15))
    map_df.plot(ax=ax, alpha=0.4, color='grey')

    # Dibuja vectores de viento en las ubicaciones de las ciudades para cada dirección única
    for wind_dir in unique_wind_directions:
        wind_dir_df = df_filtered[df_filtered['WindGustDir'] == wind_dir]

        for index, row in wind_dir_df.iterrows():
            city = row['Location']
            lat = row['Latitude']
            lon = row['Longitude']
            wind_speed = row['WindGustSpeed']

            if not np.isnan(wind_speed):
                # Convierte la dirección del viento en un ángulo en radianes
                wind_directions = unique_wind_directions
                angle = (wind_directions.tolist().index(wind_dir) * (360/len(unique_wind_directions))) * (np.pi / 180)

                # Calcula los componentes x e y del vector de viento
                u = wind_speed * np.cos(angle)
                v = wind_speed * np.sin(angle)

                # Dibuja el vector de viento en la ubicación de la ciudad con una escala más pequeña
                ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=20, color='blue', alpha=0.7)

    # Añade un título y muestra el gráfico
    plt.title(f'Campo Vectorial de Dirección del Viento en Australia - Fecha: {date}', fontsize=16)
    plt.show()

# Ejemplo de uso:
plot_wind_vectors(gdf, '2008-12-01')

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

def calculate_wind_vectors(df, date):
    # Crea un GeoDataFrame a partir del DataFrame original
    gdf = gpd.GeoDataFrame(df, 
                           geometry=df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1), 
                           crs="EPSG:4326")

    # Filtra los datos para la fecha especificada
    df_filtered = gdf[gdf['Date'] == date]

    if df_filtered.empty:
        print(f"No hay datos disponibles para la fecha {date}.")
        return

    # Obtiene todas las direcciones únicas del viento presentes en los datos filtrados
    unique_wind_directions = df_filtered['WindGustDir'].dropna().unique()

    # Crea un gráfico del mapa de Australia
    fig, ax = plt.subplots(figsize=(15, 15))
    map_df.plot(ax=ax, alpha=0.4, color='grey')

    # Define el espaciado de la malla de puntos
    spacing = 1.0  # Ajusta el espaciado según tus preferencias

    # Crea una malla de puntos sobre el mapa de Australia
    x = np.arange(map_df.bounds.minx.min(), map_df.bounds.maxx.max(), spacing)
    y = np.arange(map_df.bounds.miny.min(), map_df.bounds.maxy.max(), spacing)
    xx, yy = np.meshgrid(x, y)

    # Dibuja vectores de viento en la malla de puntos
    for wind_dir in unique_wind_directions:
        for i in range(len(x)):
            for j in range(len(y)):
                lon = xx[j, i]
                lat = yy[j, i]

                # Calcula la velocidad del viento para cada punto de la malla
                # Puedes calcularla de manera ficticia o usar datos reales si los tienes
                wind_speed = np.random.uniform(0, 20)  # Ejemplo de velocidad ficticia

                # Convierte la dirección del viento en un ángulo en radianes
                wind_directions = unique_wind_directions
                angle = (wind_directions.tolist().index(wind_dir) * (360/len(unique_wind_directions))) * (np.pi / 180)

                # Calcula los componentes x e y del vector de viento
                u = wind_speed * np.cos(angle)
                v = wind_speed * np.sin(angle)

                # Dibuja el vector de viento en el punto de la malla
                ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=20, color='blue', alpha=0.7)

    # Añade un título y muestra el gráfico
    plt.title(f'Campo Vectorial de Dirección del Viento en Australia - Fecha: {date}', fontsize=16)
    plt.show()

# Ejemplo de uso:
calculate_wind_vectors(gdf, '2008-12-01')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 11 line <cell line: 61>()
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=57'>58</a>     plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=59'>60</a> # Ejemplo de uso:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=60'>61</a> calculate_wind_vectors(gdf, '2008-12-01')
#
# c:\Users\guido\OneDrive\Facultad\TUIA\4to_Cuatrimestre\Aprendizaje_Automatico\Tp apat\tp_apat\map.ipynb Cell 11 line calculate_wind_vectors(df, date)
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=50'>51</a>             v = wind_speed * np.sin(angle)
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=52'>53</a>             # Dibuja el vector de viento en el punto de la malla
# ---> <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=53'>54</a>             ax.quiver(lon, lat, u, v, angles='xy', scale_units='xy', scale=1, color='blue', alpha=0.7)
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=55'>56</a> # Añade un título y muestra el gráfico
#      <a href='vscode-notebook-cell:/c%3A/Users/guido/OneDrive/Facultad/TUIA/4to_Cuatrimestre/Aprendizaje_Automatico/Tp%20apat/tp_apat/map.ipynb#X14sZmlsZQ%3D%3D?line=56'>57</a> plt.title(f'Campo Vectorial de Dirección del Viento en Australia - Fecha: {date}', fontsize=16)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_axes.py:4982, in Axes.quiver(self, *args, **kwargs)
#    4980 args = self._quiver_units(args, kwargs)
#    4981 q = mquiver.Quiver(self, *args, **kwargs)
# -> 4982 self.add_collection(q, autolim=True)
#    4983 self._request_autoscale_view()
#    4984 return q
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2247, in _AxesBase.add_collection(self, collection, autolim)
#    2242     collection.set_clip_path(self.patch)
#    2244 if autolim:
#    2245     # Make sure viewLim is not stale (mostly to match
#    2246     # pre-lazy-autoscale behavior, which is not really better).
# -> 2247     self._unstale_viewLim()
#    2248     datalim = collection.get_datalim(self.transData)
#    2249     points = datalim.get_points()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:777, in _AxesBase._unstale_viewLim(self)
#     775     for ax in self._shared_axes[name].get_siblings(self):
#     776         ax._stale_viewlims[name] = False
# --> 777 self.autoscale_view(**{f"scale{name}": scale
#     778                        for name, scale in need_scale.items()})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2862, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    2856         x_stickies = np.sort(np.concatenate([
#    2857             artist.sticky_edges.x
#    2858             for ax in self._shared_axes["x"].get_siblings(self)
#    2859             if hasattr(ax, "_children")
#    2860             for artist in ax.get_children()]))
#    2861     if self._ymargin and scaley and self._autoscaleYon:
# -> 2862         y_stickies = np.sort(np.concatenate([
#    2863             artist.sticky_edges.y
#    2864             for ax in self._shared_axes["y"].get_siblings(self)
#    2865             if hasattr(ax, "_children")
#    2866             for artist in ax.get_children()]))
#    2867 if self.get_xscale() == 'log':
#    2868     x_stickies = x_stickies[x_stickies > 0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_base.py:2863, in <listcomp>(.0)
#    2856         x_stickies = np.sort(np.concatenate([
#    2857             artist.sticky_edges.x
#    2858             for ax in self._shared_axes["x"].get_siblings(self)
#    2859             if hasattr(ax, "_children")
#    2860             for artist in ax.get_children()]))
#    2861     if self._ymargin and scaley and self._autoscaleYon:
#    2862         y_stickies = np.sort(np.concatenate([
# -> 2863             artist.sticky_edges.y
#    2864             for ax in self._shared_axes["y"].get_siblings(self)
#    2865             if hasattr(ax, "_children")
#    2866             for artist in ax.get_children()]))
#    2867 if self.get_xscale() == 'log':
#    2868     x_stickies = x_stickies[x_stickies > 0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\artist.py:1111, in Artist.sticky_edges(self)
#    1108     self.pchanged()
#    1109     self.stale = True
# -> 1111 @property
#    1112 def sticky_edges(self):
#    1113     """
#    1114     ``x`` and ``y`` sticky edge lists for autoscaling.
#    1115
#    (...)
#    1134
#    1135     """
#    1136     return self._sticky_edges
#
# KeyboardInterrupt:
